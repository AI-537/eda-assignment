# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(6,4))
plt.hist(df['total_bill'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel("Total Bill (USD)")
plt.ylabel("Frequency")
plt.title("Distribution of Total Bill (5 Bins)")
plt.show()

# %% [markdown]
# Distribution Shape: The distribution of total_bill is right-skewed (positively skewed). Most bills are on the lower side, with fewer high-value bills extending toward the right.

# %%
plt.figure(figsize=(6,4))
plt.hist(df['total_bill'], bins=20, color='orange', edgecolor='black')
plt.xlabel("Total Bill (USD)")
plt.ylabel("Frequency")
plt.title("Distribution of Total Bill (20 Bins)")
plt.show()

# %% [markdown]
# Effect of Bin Size:
# With 5 bins, the data looks more generalized and smoother, but details are lost. With 20 bins, the distribution becomes more detailed, showing finer variations and clusters, but can appear slightly noisy.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='day', y='total_bill', data=df)
plt.xlabel("Day")
plt.ylabel("Total Bill (USD)")
plt.title("Total Bill Distribution by Day")
plt.show()

# %% [markdown]
# Highest Median Total Bill: Saturday (Sat) generally shows the highest median total bill among all days.
# Outliers: Sunday shows noticeable outliers (very high bills).
# IQR Calculation Example (Sunday):
#
# Q1 :-lower quartile Q3 :- upper quartile IQR = Q3 − Q1
#
# Outlier Rule: Values below (Q1 − 1.5×IQR) or above (Q3 + 1.5×IQR) are outliers.
#
# Using this calculation, the extreme values identified in the box plot do qualify as true outliers.

# %%
# !pip install plotly

# %%
import plotly.express as px

fig = px.scatter(
    df,
    x='total_bill',
    y='tip',
    color='time',
    hover_data=['day', 'size'],
    title="Total Bill vs Tip (Colored by Time)"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Relationship between Total Bill and Tip: There is a positive correlation between total bill and tip. As the total bill increases, the tip amount generally increases.
#
# Lunch vs Dinner Patterns:Dinner transactions dominate higher bill values. Lunch transactions are mostly clustered at lower bill amounts. This shows that people tend to spend (and tip) more during dinner.
#
# Interesting Data Point: One noticeable point is a very high total bill (around $50+) with a comparatively lower tip percentage. This is interesting because it deviates from the general trend where higher bills usually have proportionally higher tips.
